# %%
# !python -V
# Out:
# Python 3.9.23

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2025/06/29 14:20:45 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/06/29 14:20:45 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/workspaces/MLOPS/experiment_tracking/mlruns/1', creation_time=1751162255945, experiment_id='1', last_update_time=1751162255945, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_csv(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
import pandas as pd

df_train = read_dataframe('./data/green_tripdata_2023-01.csv')
df_val = read_dataframe('./data/green_tripdata_2023-02.csv')
# Out:
# /tmp/ipykernel_883/3970424726.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
len(df_train), len(df_val)
# Out:
# (65946, 62574)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

import numpy as np
np.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# np.float64(6.037803764245777)

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2023-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2023-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    mse = mean_squared_error(y_val, y_pred)
    rmse = mse ** 0.5
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        mse = mean_squared_error(y_val, y_pred)
        rmse = mse ** 0.5
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:8.47848
# [0]	validation-rmse:8.47848
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [02:33:55] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:7.80174
# [1]	validation-rmse:7.801740<?, ?trial/s, best loss=?]
# [2]	validation-rmse:7.26497
# [2]	validation-rmse:7.26497
# [3]	validation-rmse:6.84605
# [3]	validation-rmse:6.84605
# [4]	validation-rmse:6.51687
# [4]	validation-rmse:6.51687
# [5]	validation-rmse:6.26609
# [5]	validation-rmse:6.26609
# [6]	validation-rmse:6.07146
# [6]	validation-rmse:6.07146
# [7]	validation-rmse:5.92446
# [7]	validation-rmse:5.92446
# [8]	validation-rmse:5.81081
# [8]	validation-rmse:5.81081
# [9]	validation-rmse:5.72683
# [9]	validation-rmse:5.72683
# [10]	validation-rmse:5.65612
# [10]	validation-rmse:5.65612
# [11]	validation-rmse:5.60652
# [11]	validation-rmse:5.60652
# [12]	validation-rmse:5.56619
# [12]	validation-rmse:5.56619
# [13]	validation-rmse:5.53044
# [13]	validation-rmse:5.53044
# [14]	validation-rmse:5.50663
# [14]	validation-rmse:5.50663
# [15]	validation-rmse:5.48581
# [15]	validation-rmse:5.48581
# [16]	validation-rmse:5.47363
# [16]	validation-rmse:5.47363
# [17]	validation-rmse:5.46408
# [17]	validation-rmse:5.46408
# [18]	validation-rmse:5.45063
# [18]	validation-rmse:5.45063
# [19]	validation-rmse:5.44170
# [19]	validation-rmse:5.44170
# [20]	validation-rmse:5.43794
# [20]	validation-rmse:5.43794
# [21]	validation-rmse:5.43249
# [21]	validation-rmse:5.43249
# [22]	validation-rmse:5.42954
# [22]	validation-rmse:5.42954
# [23]	validation-rmse:5.42628
# [23]	validation-rmse:5.42628
# [24]	validation-rmse:5.42194
# [24]	validation-rmse:5.42194
# [25]	validation-rmse:5.41828
# [25]	validation-rmse:5.41828
# [26]	validation-rmse:5.41621
# [26]	validation-rmse:5.41621
# [27]	validation-rmse:5.41571
# [27]	validation-rmse:5.41571
# [28]	validation-rmse:5.41428
# [28]	validation-rmse:5.41428
# [29]	validation-rmse:5.41375
# [29]	validation-rmse:5.41375
# [30]	validation-rmse:5.41334
# [30]	validation-rmse:5.41334
# [31]	validation-rmse:5.41273
# [31]	validation-rmse:5.41273
# [32]	validation-rmse:5.41258
# [32]	validation-rmse:5.41258
# [33]	validation-rmse:5.41061
# [33]	validation-rmse:5.41061
# [34]	validation-rmse:5.41062
# [34]	validation-rmse:5.41062
# [35]	validation-rmse:5.41037
#   0%|          | 0/50 [00:03<?, ?trial/s, best loss=?][35]	validation-rmse:5.41037
# [36]	validation-rmse:5.40998
# [36]	validation-rmse:5.40998
# [37]	validation-rmse:5.40782
# [37]	validation-rmse:5.40782
# [38]	validation-rmse:5.40770
# [38]	validation-rmse:5.40770
# [39]	validation-rmse:5.40752
# [39]	validation-rmse:5.40752
# [40]	validation-rmse:5.40709
# [40]	validation-rmse:5.40709
# [41]	validation-rmse:5.40594
# [41]	validation-rmse:5.40594
# [42]	validation-rmse:5.40508
# [42]	validation-rmse:5.40508
# [43]	validation-rmse:5.40433
# [43]	validation-rmse:5.40433
# [44]	validation-rmse:5.40360
# [44]	validation-rmse:5.40360
# [45]	validation-rmse:5.40266
# [45]	validation-rmse:5.40266
# [46]	validation-rmse:5.40247
# [46]	validation-rmse:5.40247
# [47]	validation-rmse:5.40136
# [47]	validation-rmse:5.40136
# [48]	validation-rmse:5.39980
# [48]	validation-rmse:5.39980
# [49]	validation-rmse:5.39912
# [49]	validation-rmse:5.39912
# [50]	validation-rmse:5.39782
# [50]	validation-rmse:5.39782
# [51]	validation-rmse:5.39744
# [51]	validation-rmse:5.39744
# [52]	validation-rmse:5.39621
# [52]	validation-rmse:5.39621
# [53]	validation-rmse:5.39427
# [53]	validation-rmse:5.39427
# [54]	validation-rmse:5.39390
# [54]	validation-rmse:5.39390
# [55]	validation-rmse:5.39254
# [55]	validation-rmse:5.39254
# [56]	validation-rmse:5.39106
# [56]	validation-rmse:5.39106
# [57]	validation-rmse:5.39093
# [57]	validation-rmse:5.39093
# [58]	validation-rmse:5.38984
# [58]	validation-rmse:5.38984
# [59]	validation-rmse:5.38944
# [59]	validation-rmse:5.38944
# [60]	validation-rmse:5.38815
# [60]	validation-rmse:5.38815
# [61]	validation-rmse:5.38700
# [61]	validation-rmse:5.38700
# [62]	validation-rmse:5.38674
# [62]	validation-rmse:5.38674
# [63]	validation-rmse:5.38635
# [63]	validation-rmse:5.38635
# [64]	validation-rmse:5.38543
# [64]	validation-rmse:5.38543
# [65]	validation-rmse:5.38471
# [65]	validation-rmse:5.38471
# [66]	validation-rmse:5.38394
# [66]	validation-rmse:5.38394
# [67]	validation-rmse:5.38411
# [67]	validation-rmse:5.38411
# [68]	validation-rmse:5.38351
# [68]	validation-rmse:5.38351
# [69]	validation-rmse:5.38338
# [69]	validation-rmse:5.38338
# [70]	validation-rmse:5.38290
# [70]	validation-rmse:5.38290
# [71]	validation-rmse:5.38168
# [71]	validation-rmse:5.38168
# [72]	validation-rmse:5.38099
# [72]	validation-rmse:5.38099
# [73]	validation-rmse:5.38033
# [73]	validation-rmse:5.38033
# [74]	validation-rmse:5.37908
# [74]	validation-rmse:5.37908
# [75]	validation-rmse:5.37822
# [75]	validation-rmse:5.37822
# [76]	validation-rmse:5.37701
# [76]	validation-rmse:5.37701
# [77]	validation-rmse:5.37658
# [77]	validation-rmse:5.37658
# [78]	validation-rmse:5.37541
# [78]	validation-rmse:5.37541
# [79]	validation-rmse:5.37457
# [79]	validation-rmse:5.37457
# [80]	validation-rmse:5.37172
# [80]	validation-rmse:5.37172
# [81]	validation-rmse:5.37098
# [81]	validation-rmse:5.37098
# [82]	validation-rmse:5.37107
# [82]	validation-rmse:5.37107
# [83]	validation-rmse:5.37021
# [83]	validation-rmse:5.37021
# [84]	validation-rmse:5.36958
# [84]	validation-rmse:5.36958
# [85]	validation-rmse:5.36848
# [85]	validation-rmse:5.36848
# [86]	validation-rmse:5.36824
# [86]	validation-rmse:5.36824
# [87]	validation-rmse:5.36625
# [87]	validation-rmse:5.36625
# [88]	validation-rmse:5.36576
# [88]	validation-rmse:5.36576
# [89]	validation-rmse:5.36548
# [89]	validation-rmse:5.36548
# [90]	validation-rmse:5.36529
# [90]	validation-rmse:5.36529
# [91]	validation-rmse:5.36443
# [91]	validation-rmse:5.36443
# [92]	validation-rmse:5.36406
# [92]	validation-rmse:5.36406
# [93]	validation-rmse:5.36321
# [93]	validation-rmse:5.36321
# [94]	validation-rmse:5.36249
# [94]	validation-rmse:5.36249
# [95]	validation-rmse:5.36141
# [95]	validation-rmse:5.36141
# [96]	validation-rmse:5.36016
# [96]	validation-rmse:5.36016
# [97]	validation-rmse:5.35982
# [97]	validation-rmse:5.35982
# [98]	validation-rmse:5.35909
# [98]	validation-rmse:5.35909
# [99]	validation-rmse:5.35842
# [99]	validation-rmse:5.35842
# [100]	validation-rmse:5.35795
# [100]	validation-rmse:5.35795
# [101]	validation-rmse:5.35761
# [101]	validation-rmse:5.35761
# [102]	validation-rmse:5.35659
# [102]	validation-rmse:5.35659
# [103]	validation-rmse:5.35543
# [103]	validation-rmse:5.35543
# [104]	validation-rmse:5.35488
# [104]	validation-rmse:5.35488
# [105]	validation-rmse:5.35433
# [105]	validation-rmse:5.35433
# [106]	validation-rmse:5.35411
# [106]	validation-rmse:5.35411
# [107]	validation-rmse:5.35432
# [107]	validation-rmse:5.35432
# [108]	validation-rmse:5.35429
# [108]	validation-rmse:5.35429
# [109]	validation-rmse:5.35380
# [109]	validation-rmse:5.35380
# [110]	validation-rmse:5.35341
# [110]	validation-rmse:5.35341
# [111]	validation-rmse:5.35311
# [111]	validation-rmse:5.35311
# [112]	validation-rmse:5.35262
# [112]	validation-rmse:5.35262
# [113]	validation-rmse:5.35214
# [113]	validation-rmse:5.35214
# [114]	validation-rmse:5.35197
# [114]	validation-rmse:5.35197
# [115]	validation-rmse:5.35172
# [115]	validation-rmse:5.35172
# [116]	validation-rmse:5.35133
# [116]	validation-rmse:5.35133
# [117]	validation-rmse:5.35183
# [117]	validation-rmse:5.35183
# [118]	validation-rmse:5.35141
# [118]	validation-rmse:5.35141
# [119]	validation-rmse:5.35072
# [119]	validation-rmse:5.35072
# [120]	validation-rmse:5.35112
# [120]	validation-rmse:5.35112
# [121]	validation-rmse:5.35045
# [121]	validation-rmse:5.35045
# [122]	validation-rmse:5.35035
# [122]	validation-rmse:5.35035
# [123]	validation-rmse:5.35028
# [123]	validation-rmse:5.35028
# [124]	validation-rmse:5.34874
# [124]	validation-rmse:5.34874
# [125]	validation-rmse:5.34845
# [125]	validation-rmse:5.34845
# [126]	validation-rmse:5.34773
# [126]	validation-rmse:5.34773
# [127]	validation-rmse:5.34723
# [127]	validation-rmse:5.34723
# [128]	validation-rmse:5.34682
# [128]	validation-rmse:5.34682
# [129]	validation-rmse:5.34592
# [129]	validation-rmse:5.34592
# [130]	validation-rmse:5.34554
# [130]	validation-rmse:5.34554
# [131]	validation-rmse:5.34506
# [131]	validation-rmse:5.34506
# [132]	validation-rmse:5.34483
# [132]	validation-rmse:5.34483
# [133]	validation-rmse:5.34417
# [133]	validation-rmse:5.34417
# [134]	validation-rmse:5.34348
# [134]	validation-rmse:5.34348
# [135]	validation-rmse:5.34196
# [135]	validation-rmse:5.34196
# [136]	validation-rmse:5.34155
# [136]	validation-rmse:5.34155
# [137]	validation-rmse:5.34135
# [137]	validation-rmse:5.34135
# [138]	validation-rmse:5.34123
# [138]	validation-rmse:5.34123
# [139]	validation-rmse:5.34127
# [139]	validation-rmse:5.34127
# [140]	validation-rmse:5.34052
# [140]	validation-rmse:5.34052
# [141]	validation-rmse:5.33971
# [141]	validation-rmse:5.33971
# [142]	validation-rmse:5.33936
# [142]	validation-rmse:5.33936
# [143]	validation-rmse:5.33910
# [143]	validation-rmse:5.33910
# [144]	validation-rmse:5.33717
# [144]	validation-rmse:5.33717
# [145]	validation-rmse:5.33681
# [145]	validation-rmse:5.33681
# [146]	validation-rmse:5.33657
# [146]	validation-rmse:5.33657
# [147]	validation-rmse:5.33590
# [147]	validation-rmse:5.33590
# [148]	validation-rmse:5.33555
# [148]	validation-rmse:5.33555
# [149]	validation-rmse:5.33529
# [149]	validation-rmse:5.33529
# [150]	validation-rmse:5.33464
# [150]	validation-rmse:5.33464
# [151]	validation-rmse:5.33437
# [151]	validation-rmse:5.33437
# [152]	validation-rmse:5.33408
# [152]	validation-rmse:5.33408
# [153]	validation-rmse:5.33341
# [153]	validation-rmse:5.33341
# [154]	validation-rmse:5.33325
# [154]	validation-rmse:5.33325
# [155]	validation-rmse:5.33299
# [155]	validation-rmse:5.33299
# [156]	validation-rmse:5.33305
# [156]	validation-rmse:5.33305
# [157]	validation-rmse:5.33239
# [157]	validation-rmse:5.33239
# [158]	validation-rmse:5.33168
# [158]	validation-rmse:5.33168
# [159]	validation-rmse:5.33068
# [159]	validation-rmse:5.33068
# [160]	validation-rmse:5.33039
# [160]	validation-rmse:5.33039
# [161]	validation-rmse:5.32992
# [161]	validation-rmse:5.32992
# [162]	validation-rmse:5.32931
# [162]	validation-rmse:5.32931
# [163]	validation-rmse:5.32848
# [163]	validation-rmse:5.32848
# [164]	validation-rmse:5.32833
# [164]	validation-rmse:5.32833
# [165]	validation-rmse:5.32712
# [165]	validation-rmse:5.32712
# [166]	validation-rmse:5.32667
# [166]	validation-rmse:5.32667
# [167]	validation-rmse:5.32648
# [167]	validation-rmse:5.32648
# [168]	validation-rmse:5.32614
# [168]	validation-rmse:5.32614
# [169]	validation-rmse:5.32533
# [169]	validation-rmse:5.32533
# [170]	validation-rmse:5.32534
# [170]	validation-rmse:5.32534
# [171]	validation-rmse:5.32527
# [171]	validation-rmse:5.32527
# [172]	validation-rmse:5.32522
# [172]	validation-rmse:5.32522
# [173]	validation-rmse:5.32489
# [173]	validation-rmse:5.32489
# [174]	validation-rmse:5.32464
# [174]	validation-rmse:5.32464
# [175]	validation-rmse:5.32452
# [175]	validation-rmse:5.32452
# [176]	validation-rmse:5.32392
# [176]	validation-rmse:5.32392
# [177]	validation-rmse:5.32363
# [177]	validation-rmse:5.32363
# [178]	validation-rmse:5.32246
# [178]	validation-rmse:5.32246
# [179]	validation-rmse:5.32248
# [179]	validation-rmse:5.32248
# [180]	validation-rmse:5.32273
# [180]	validation-rmse:5.32273
# [181]	validation-rmse:5.32232
# [181]	validation-rmse:5.32232
# [182]	validation-rmse:5.32194
# [182]	validation-rmse:5.32194
# [183]	validation-rmse:5.32180
# [183]	validation-rmse:5.32180
# [184]	validation-rmse:5.32161
# [184]	validation-rmse:5.32161
# [185]	validation-rmse:5.32126
# [185]	validation-rmse:5.32126
# [186]	validation-rmse:5.32068
# [186]	validation-rmse:5.32068
# [187]	validation-rmse:5.32017
# [187]	validation-rmse:5.32017
# [188]	validation-rmse:5.32025
# [188]	validation-rmse:5.32025
# [189]	validation-rmse:5.31996
# [189]	validation-rmse:5.31996
# [190]	validation-rmse:5.31907
# [190]	validation-rmse:5.31907
# [191]	validation-rmse:5.31967
# [191]	validation-rmse:5.31967
# [192]	validation-rmse:5.31933
# [192]	validation-rmse:5.31933
# [193]	validation-rmse:5.31917
# [193]	validation-rmse:5.31917
# [194]	validation-rmse:5.31888
# [194]	validation-rmse:5.31888
# [195]	validation-rmse:5.31863
# [195]	validation-rmse:5.31863
# [196]	validation-rmse:5.31821
# [196]	validation-rmse:5.31821
# [197]	validation-rmse:5.31849
# [197]	validation-rmse:5.31849
# [198]	validation-rmse:5.31797
# [198]	validation-rmse:5.31797
# [199]	validation-rmse:5.31808
# [199]	validation-rmse:5.31808
# [200]	validation-rmse:5.31865
# [200]	validation-rmse:5.31865
# [201]	validation-rmse:5.31778
# [201]	validation-rmse:5.31778
# [202]	validation-rmse:5.31769
# [202]	validation-rmse:5.31769
# [203]	validation-rmse:5.31746
# [203]	validation-rmse:5.31746
# [204]	validation-rmse:5.31711
# [204]	validation-rmse:5.31711
# [205]	validation-rmse:5.31706
# [205]	validation-rmse:5.31706
# [206]	validation-rmse:5.31451
# [206]	validation-rmse:5.31451
# [207]	validation-rmse:5.31329
# [207]	validation-rmse:5.31329
# [208]	validation-rmse:5.31329
# [208]	validation-rmse:5.31329
# [209]	validation-rmse:5.31306
# [209]	validation-rmse:5.31306
# [210]	validation-rmse:5.31299
# [210]	validation-rmse:5.31299
# [211]	validation-rmse:5.31222
# [211]	validation-rmse:5.31222
# [212]	validation-rmse:5.31126
# [212]	validation-rmse:5.31126
# [213]	validation-rmse:5.31113
# [213]	validation-rmse:5.31113
# [214]	validation-rmse:5.31087
# [214]	validation-rmse:5.31087
# [215]	validation-rmse:5.31042
# [215]	validation-rmse:5.31042
# [216]	validation-rmse:5.31011
# [216]	validation-rmse:5.31011
# [217]	validation-rmse:5.30962
# [217]	validation-rmse:5.30962
# [218]	validation-rmse:5.30916
# [218]	validation-rmse:5.30916
# [219]	validation-rmse:5.30869
# [219]	validation-rmse:5.30869
# [220]	validation-rmse:5.30841
# [220]	validation-rmse:5.30841
# [221]	validation-rmse:5.30738
# [221]	validation-rmse:5.30738
# [222]	validation-rmse:5.30763
# [222]	validation-rmse:5.30763
# [223]	validation-rmse:5.30722
# [223]	validation-rmse:5.30722
# [224]	validation-rmse:5.30724
# [224]	validation-rmse:5.30724
# [225]	validation-rmse:5.30753
# [225]	validation-rmse:5.30753
# [226]	validation-rmse:5.30735
# [226]	validation-rmse:5.30735
# [227]	validation-rmse:5.30637
# [227]	validation-rmse:5.30637
# [228]	validation-rmse:5.30623
# [228]	validation-rmse:5.30623
# [229]	validation-rmse:5.30469
# [229]	validation-rmse:5.30469
# [230]	validation-rmse:5.30453
# [230]	validation-rmse:5.30453
# [231]	validation-rmse:5.30421
#   0%|          | 0/50 [00:15<?, ?trial/s, best loss=?][231]	validation-rmse:5.30421
# [232]	validation-rmse:5.30383
# [232]	validation-rmse:5.30383
# [233]	validation-rmse:5.30328
# [233]	validation-rmse:5.30328
# [234]	validation-rmse:5.30275
# [234]	validation-rmse:5.30275
# [235]	validation-rmse:5.30257
# [235]	validation-rmse:5.30257
# [236]	validation-rmse:5.30225
# [236]	validation-rmse:5.30225
# [237]	validation-rmse:5.30217
# [237]	validation-rmse:5.30217
# [238]	validation-rmse:5.30187
# [238]	validation-rmse:5.30187
# [239]	validation-rmse:5.30187
# [239]	validation-rmse:5.30187
# [240]	validation-rmse:5.30116
# [240]	validation-rmse:5.30116
# [241]	validation-rmse:5.30083
# [241]	validation-rmse:5.30083
# [242]	validation-rmse:5.30066
# [242]	validation-rmse:5.30066
# [243]	validation-rmse:5.29954
# [243]	validation-rmse:5.29954
# [244]	validation-rmse:5.29949
# [244]	validation-rmse:5.29949
# [245]	validation-rmse:5.29896
# [245]	validation-rmse:5.29896
# [246]	validation-rmse:5.29950
# [246]	validation-rmse:5.29950
# [247]	validation-rmse:5.29966
# [247]	validation-rmse:5.29966
# [248]	validation-rmse:5.29945
# [248]	validation-rmse:5.29945
# [249]	validation-rmse:5.29919
# [249]	validation-rmse:5.29919
# [250]	validation-rmse:5.29876
# [250]	validation-rmse:5.29876
# [251]	validation-rmse:5.29814
# [251]	validation-rmse:5.29814
# [252]	validation-rmse:5.29748
# [252]	validation-rmse:5.29748
# [253]	validation-rmse:5.29734
# [253]	validation-rmse:5.29734
# [254]	validation-rmse:5.29675
# [254]	validation-rmse:5.29675
# [255]	validation-rmse:5.29649
# [255]	validation-rmse:5.29649
# [256]	validation-rmse:5.29647
# [256]	validation-rmse:5.29647
# [257]	validation-rmse:5.29609
# [257]	validation-rmse:5.29609
# [258]	validation-rmse:5.29555
# [258]	validation-rmse:5.29555
# [259]	validation-rmse:5.29528
# [259]	validation-rmse:5.29528
# [260]	validation-rmse:5.29564
# [260]	validation-rmse:5.29564
# [261]	validation-rmse:5.29548
# [261]	validation-rmse:5.29548
# [262]	validation-rmse:5.29536
# [262]	validation-rmse:5.29536
# [263]	validation-rmse:5.29534
# [263]	validation-rmse:5.29534
# [264]	validation-rmse:5.29406
# [264]	validation-rmse:5.29406
# [265]	validation-rmse:5.29405
# [265]	validation-rmse:5.29405
# [266]	validation-rmse:5.29354
# [266]	validation-rmse:5.29354
# [267]	validation-rmse:5.29327
# [267]	validation-rmse:5.29327
# [268]	validation-rmse:5.29288
# [268]	validation-rmse:5.29288
# [269]	validation-rmse:5.29240
# [269]	validation-rmse:5.29240
# [270]	validation-rmse:5.29217
# [270]	validation-rmse:5.29217
# [271]	validation-rmse:5.29209
# [271]	validation-rmse:5.29209
# [272]	validation-rmse:5.29174
# [272]	validation-rmse:5.29174
# [273]	validation-rmse:5.29146
# [273]	validation-rmse:5.29146
# [274]	validation-rmse:5.29082
# [274]	validation-rmse:5.29082
# [275]	validation-rmse:5.29074
# [275]	validation-rmse:5.29074
# [276]	validation-rmse:5.29044
# [276]	validation-rmse:5.29044
# [277]	validation-rmse:5.29022
# [277]	validation-rmse:5.29022
# [278]	validation-rmse:5.28958
# [278]	validation-rmse:5.28958
# [279]	validation-rmse:5.28948
# [279]	validation-rmse:5.28948
# [280]	validation-rmse:5.28887
# [280]	validation-rmse:5.28887
# [281]	validation-rmse:5.28829
# [281]	validation-rmse:5.28829
# [282]	validation-rmse:5.28811
# [282]	validation-rmse:5.28811
# [283]	validation-rmse:5.28851
# [283]	validation-rmse:5.28851
# [284]	validation-rmse:5.28816
# [284]	validation-rmse:5.28816
# [285]	validation-rmse:5.28790
# [285]	validation-rmse:5.28790
# [286]	validation-rmse:5.28759
# [286]	validation-rmse:5.28759
# [287]	validation-rmse:5.28749
# [287]	validation-rmse:5.28749
# [288]	validation-rmse:5.28714
# [288]	validation-rmse:5.28714
# [289]	validation-rmse:5.28686
# [289]	validation-rmse:5.28686
# [290]	validation-rmse:5.28647
# [290]	validation-rmse:5.28647
# [291]	validation-rmse:5.28641
# [291]	validation-rmse:5.28641
# [292]	validation-rmse:5.28602
# [292]	validation-rmse:5.28602
# [293]	validation-rmse:5.28697
# [293]	validation-rmse:5.28697
# [294]	validation-rmse:5.28668
# [294]	validation-rmse:5.28668
# [295]	validation-rmse:5.28651
# [295]	validation-rmse:5.28651
# [296]	validation-rmse:5.28632
# [296]	validation-rmse:5.28632
# [297]	validation-rmse:5.28624
# [297]	validation-rmse:5.28624
# [298]	validation-rmse:5.28596
# [298]	validation-rmse:5.28596
# [299]	validation-rmse:5.28579
# [299]	validation-rmse:5.28579
# [300]	validation-rmse:5.28569
# [300]	validation-rmse:5.28569
# [301]	validation-rmse:5.28552
# [301]	validation-rmse:5.28552
# [302]	validation-rmse:5.28503
# [302]	validation-rmse:5.28503
# [303]	validation-rmse:5.28486
# [303]	validation-rmse:5.28486
# [304]	validation-rmse:5.28439
# [304]	validation-rmse:5.28439
# [305]	validation-rmse:5.28392
# [305]	validation-rmse:5.28392
# [306]	validation-rmse:5.28392
# [306]	validation-rmse:5.28392
# [307]	validation-rmse:5.28414
# [307]	validation-rmse:5.28414
# [308]	validation-rmse:5.28355
# [308]	validation-rmse:5.28355
# [309]	validation-rmse:5.28334
# [309]	validation-rmse:5.28334
# [310]	validation-rmse:5.28290
# [310]	validation-rmse:5.28290
# [311]	validation-rmse:5.28302
# [311]	validation-rmse:5.28302
# [312]	validation-rmse:5.28311
# [312]	validation-rmse:5.28311
# [313]	validation-rmse:5.28264
# [313]	validation-rmse:5.28264
# [314]	validation-rmse:5.28235
# [314]	validation-rmse:5.28235
# [315]	validation-rmse:5.28221
# [315]	validation-rmse:5.28221
# [316]	validation-rmse:5.28207
# [316]	validation-rmse:5.28207
# [317]	validation-rmse:5.28219
# [317]	validation-rmse:5.28219
# [318]	validation-rmse:5.28137
# [318]	validation-rmse:5.28137
# [319]	validation-rmse:5.28137
# [319]	validation-rmse:5.28137
# [320]	validation-rmse:5.28112
# [320]	validation-rmse:5.28112
# [321]	validation-rmse:5.28059
# [321]	validation-rmse:5.28059
# [322]	validation-rmse:5.28016
# [322]	validation-rmse:5.28016
# [323]	validation-rmse:5.27982
# [323]	validation-rmse:5.27982
# [324]	validation-rmse:5.27958
# [324]	validation-rmse:5.27958
# [325]	validation-rmse:5.27949
# [325]	validation-rmse:5.27949
# [326]	validation-rmse:5.27950
#   0%|          | 0/50 [00:21<?, ?trial/s, best loss=?][326]	validation-rmse:5.27950
# [327]	validation-rmse:5.27928
# [327]	validation-rmse:5.27928
# [328]	validation-rmse:5.27908
# [328]	validation-rmse:5.27908
# [329]	validation-rmse:5.27846
# [329]	validation-rmse:5.27846
# [330]	validation-rmse:5.27780
# [330]	validation-rmse:5.27780
# [331]	validation-rmse:5.27775
# [331]	validation-rmse:5.27775
# [332]	validation-rmse:5.27753
# [332]	validation-rmse:5.27753
# [333]	validation-rmse:5.27729
# [333]	validation-rmse:5.27729
# [334]	validation-rmse:5.27677
# [334]	validation-rmse:5.27677
# [335]	validation-rmse:5.27653
# [335]	validation-rmse:5.27653
# [336]	validation-rmse:5.27652
# [336]	validation-rmse:5.27652?, ?trial/s, best loss=?]
# [337]	validation-rmse:5.27617
# [337]	validation-rmse:5.27617
# [338]	validation-rmse:5.27606
# [338]	validation-rmse:5.27606
# [339]	validation-rmse:5.27586
# [339]	validation-rmse:5.27586
# [340]	validation-rmse:5.27594
# [340]	validation-rmse:5.27594
# [341]	validation-rmse:5.27571
# [341]	validation-rmse:5.27571
# [342]	validation-rmse:5.27556
# [342]	validation-rmse:5.27556
# [343]	validation-rmse:5.27528
# [343]	validation-rmse:5.27528
# [344]	validation-rmse:5.27447
# [344]	validation-rmse:5.27447
# [345]	validation-rmse:5.27442
# [345]	validation-rmse:5.27442
# [346]	validation-rmse:5.27447
# [346]	validation-rmse:5.27447
# [347]	validation-rmse:5.27412
# [347]	validation-rmse:5.27412
# [348]	validation-rmse:5.27461
# [348]	validation-rmse:5.27461?, ?trial/s, best loss=?]
# [349]	validation-rmse:5.27442
# [349]	validation-rmse:5.27442
# [350]	validation-rmse:5.27442
# [350]	validation-rmse:5.27442
# [351]	validation-rmse:5.27402
# [351]	validation-rmse:5.27402
# [352]	validation-rmse:5.27382
# [352]	validation-rmse:5.27382
# [353]	validation-rmse:5.27366
# [353]	validation-rmse:5.27366
# [354]	validation-rmse:5.27355
# [354]	validation-rmse:5.27355
# [355]	validation-rmse:5.27349
# [355]	validation-rmse:5.27349
# [356]	validation-rmse:5.27335
# [356]	validation-rmse:5.27335
# [357]	validation-rmse:5.27290
# [357]	validation-rmse:5.27290
# [358]	validation-rmse:5.27254
# [358]	validation-rmse:5.27254
# [359]	validation-rmse:5.27264
# [359]	validation-rmse:5.27264
# [360]	validation-rmse:5.27243
# [360]	validation-rmse:5.27243
# [361]	validation-rmse:5.27230
# [361]	validation-rmse:5.27230
# [362]	validation-rmse:5.27213
# [362]	validation-rmse:5.27213
# [363]	validation-rmse:5.27174
# [363]	validation-rmse:5.27174
# [364]	validation-rmse:5.27159
# [364]	validation-rmse:5.27159
# [365]	validation-rmse:5.27140
# [365]	validation-rmse:5.27140
# [366]	validation-rmse:5.27121
# [366]	validation-rmse:5.27121
# [367]	validation-rmse:5.27096
# [367]	validation-rmse:5.27096
# [368]	validation-rmse:5.27071
# [368]	validation-rmse:5.27071
# [369]	validation-rmse:5.27034
# [369]	validation-rmse:5.27034
# [370]	validation-rmse:5.27026
# [370]	validation-rmse:5.27026
# [371]	validation-rmse:5.27024
# [371]	validation-rmse:5.27024
# [372]	validation-rmse:5.27014
# [372]	validation-rmse:5.27014
# [373]	validation-rmse:5.27034
# [373]	validation-rmse:5.27034
# [374]	validation-rmse:5.26896
# [374]	validation-rmse:5.26896
# [375]	validation-rmse:5.26879
# [375]	validation-rmse:5.26879
# [376]	validation-rmse:5.26874
#   0%|          | 0/50 [00:24<?, ?trial/s, best loss=?][376]	validation-rmse:5.26874
# [377]	validation-rmse:5.26806
# [377]	validation-rmse:5.26806
# [378]	validation-rmse:5.26772
# [378]	validation-rmse:5.26772
# [379]	validation-rmse:5.26780
# [379]	validation-rmse:5.26780
# [380]	validation-rmse:5.26781
# [380]	validation-rmse:5.26781
# [381]	validation-rmse:5.26792
# [381]	validation-rmse:5.26792?, ?trial/s, best loss=?]
# [382]	validation-rmse:5.26747
# [382]	validation-rmse:5.26747
# [383]	validation-rmse:5.26656
# [383]	validation-rmse:5.26656
# [384]	validation-rmse:5.26639
# [384]	validation-rmse:5.26639
# [385]	validation-rmse:5.26632
# [385]	validation-rmse:5.26632
# [386]	validation-rmse:5.26631
# [386]	validation-rmse:5.26631
# [387]	validation-rmse:5.26640
# [387]	validation-rmse:5.26640
# [388]	validation-rmse:5.26624
# [388]	validation-rmse:5.26624
# [389]	validation-rmse:5.26595
# [389]	validation-rmse:5.26595
# [390]	validation-rmse:5.26546
# [390]	validation-rmse:5.26546
# [391]	validation-rmse:5.26561
# [391]	validation-rmse:5.26561
# [392]	validation-rmse:5.26534
# [392]	validation-rmse:5.26534
# [393]	validation-rmse:5.26539
# [393]	validation-rmse:5.26539
# [394]	validation-rmse:5.26507
# [394]	validation-rmse:5.26507
# [395]	validation-rmse:5.26523
# [395]	validation-rmse:5.26523
# [396]	validation-rmse:5.26497
# [396]	validation-rmse:5.26497
# [397]	validation-rmse:5.26417
# [397]	validation-rmse:5.26417
# [398]	validation-rmse:5.26411
# [398]	validation-rmse:5.26411
# [399]	validation-rmse:5.26412
# [399]	validation-rmse:5.26412
# [400]	validation-rmse:5.26396
# [400]	validation-rmse:5.26396
# [401]	validation-rmse:5.26382
# [401]	validation-rmse:5.26382
# [402]	validation-rmse:5.26369
# [402]	validation-rmse:5.26369
# [403]	validation-rmse:5.26332
# [403]	validation-rmse:5.26332
# [404]	validation-rmse:5.26306
# [404]	validation-rmse:5.26306
# [405]	validation-rmse:5.26286
# [405]	validation-rmse:5.26286
# [406]	validation-rmse:5.26253
# [406]	validation-rmse:5.26253
# [407]	validation-rmse:5.26241
# [407]	validation-rmse:5.26241
# [408]	validation-rmse:5.26234
# [408]	validation-rmse:5.26234
# [409]	validation-rmse:5.26236
# [409]	validation-rmse:5.26236
# [410]	validation-rmse:5.26219
# [410]	validation-rmse:5.26219
# [411]	validation-rmse:5.26155
# [411]	validation-rmse:5.26155
# [412]	validation-rmse:5.26134
# [412]	validation-rmse:5.26134
# [413]	validation-rmse:5.26111
# [413]	validation-rmse:5.26111
# [414]	validation-rmse:5.26091
# [414]	validation-rmse:5.26091
# [415]	validation-rmse:5.26055
# [415]	validation-rmse:5.26055
# [416]	validation-rmse:5.26096
# [416]	validation-rmse:5.26096
# [417]	validation-rmse:5.26069
# [417]	validation-rmse:5.26069
# [418]	validation-rmse:5.26074
# [418]	validation-rmse:5.26074
# [419]	validation-rmse:5.26075
# [419]	validation-rmse:5.26075
# [420]	validation-rmse:5.26059
# [420]	validation-rmse:5.26059
# [421]	validation-rmse:5.26061
# [421]	validation-rmse:5.26061
# [422]	validation-rmse:5.26039
# [422]	validation-rmse:5.26039
# [423]	validation-rmse:5.26019
# [423]	validation-rmse:5.26019
# [424]	validation-rmse:5.26014
# [424]	validation-rmse:5.26014
# [425]	validation-rmse:5.25990
# [425]	validation-rmse:5.25990
# [426]	validation-rmse:5.26041
# [426]	validation-rmse:5.26041
# [427]	validation-rmse:5.25941
# [427]	validation-rmse:5.25941
# [428]	validation-rmse:5.25908
# [428]	validation-rmse:5.25908
# [429]	validation-rmse:5.25841
# [429]	validation-rmse:5.25841
# [430]	validation-rmse:5.25835
# [430]	validation-rmse:5.25835
# [431]	validation-rmse:5.25818
# [431]	validation-rmse:5.25818
# ...
# [771]	validation-rmse:5.22114
# [772]	validation-rmse:5.22044
# [772]	validation-rmse:5.22044
# [773]	validation-rmse:5.22041
# [773]	validation-rmse:5.22041
# [774]	validation-rmse:5.22015
# [774]	validation-rmse:5.22015
# [775]	validation-rmse:5.22004
# [775]	validation-rmse:5.22004
# [776]	validation-rmse:5.22007
# [776]	validation-rmse:5.22007
# [777]	validation-rmse:5.22009
# [777]	validation-rmse:5.22009
# [778]	validation-rmse:5.21991
# [778]	validation-rmse:5.21991
# [779]	validation-rmse:5.21981
# [779]	validation-rmse:5.21981
# [780]	validation-rmse:5.21986
# [780]	validation-rmse:5.21986
# [781]	validation-rmse:5.21987
# [781]	validation-rmse:5.21987
# [782]	validation-rmse:5.21948
# [782]	validation-rmse:5.21948
# [783]	validation-rmse:5.21941
# [783]	validation-rmse:5.21941
# [784]	validation-rmse:5.21906
# [784]	validation-rmse:5.21906
# [785]	validation-rmse:5.21898
# [785]	validation-rmse:5.21898
# [786]	validation-rmse:5.21914
# [786]	validation-rmse:5.21914
# [787]	validation-rmse:5.21878
# [787]	validation-rmse:5.21878
# [788]	validation-rmse:5.21879
# [788]	validation-rmse:5.21879
# [789]	validation-rmse:5.21865
# [789]	validation-rmse:5.21865
# [790]	validation-rmse:5.21853
# [790]	validation-rmse:5.21853
# [791]	validation-rmse:5.21832
# [791]	validation-rmse:5.21832
# [792]	validation-rmse:5.21816
# [792]	validation-rmse:5.21816
# [793]	validation-rmse:5.21832
# [793]	validation-rmse:5.21832
# [794]	validation-rmse:5.21825
# [794]	validation-rmse:5.21825
# [795]	validation-rmse:5.21811
# [795]	validation-rmse:5.21811
# [796]	validation-rmse:5.21815
# [796]	validation-rmse:5.21815
# [797]	validation-rmse:5.21803
# [797]	validation-rmse:5.21803
# [798]	validation-rmse:5.21804
# [798]	validation-rmse:5.21804
# [799]	validation-rmse:5.21799
# [799]	validation-rmse:5.21799
# [800]	validation-rmse:5.21789
# [800]	validation-rmse:5.21789
# [801]	validation-rmse:5.21759
# [801]	validation-rmse:5.21759
# [802]	validation-rmse:5.21724
# [802]	validation-rmse:5.21724
# [803]	validation-rmse:5.21778
# [803]	validation-rmse:5.21778
# [804]	validation-rmse:5.21790
# [804]	validation-rmse:5.21790
# [805]	validation-rmse:5.21804
# [805]	validation-rmse:5.21804
# [806]	validation-rmse:5.21799
# [806]	validation-rmse:5.21799
# [807]	validation-rmse:5.21809
# [807]	validation-rmse:5.21809
# [808]	validation-rmse:5.21799
# [808]	validation-rmse:5.21799
# [809]	validation-rmse:5.21813
# [809]	validation-rmse:5.21813
# [810]	validation-rmse:5.21776
# [810]	validation-rmse:5.21776
# [811]	validation-rmse:5.21781
# [811]	validation-rmse:5.21781
# [812]	validation-rmse:5.21778
# [812]	validation-rmse:5.21778
# [813]	validation-rmse:5.21760
# [813]	validation-rmse:5.21760
# [814]	validation-rmse:5.21751
# [814]	validation-rmse:5.21751
# [815]	validation-rmse:5.21749
# [815]	validation-rmse:5.21749
# [816]	validation-rmse:5.21764
# [816]	validation-rmse:5.21764
# [817]	validation-rmse:5.21781
# [817]	validation-rmse:5.21781
# [818]	validation-rmse:5.21785
# [818]	validation-rmse:5.21785
# [819]	validation-rmse:5.21776
# [819]	validation-rmse:5.21776
# [820]	validation-rmse:5.21768
# [820]	validation-rmse:5.21768
# [821]	validation-rmse:5.21760
# [821]	validation-rmse:5.21760
# [822]	validation-rmse:5.21743
# [822]	validation-rmse:5.21743
# [823]	validation-rmse:5.21737
# [823]	validation-rmse:5.21737
# [824]	validation-rmse:5.21777
# [824]	validation-rmse:5.21777
# [825]	validation-rmse:5.21752
# [825]	validation-rmse:5.21752
# [826]	validation-rmse:5.21759
# [826]	validation-rmse:5.21759
# [827]	validation-rmse:5.21767
# [827]	validation-rmse:5.21767
# [828]	validation-rmse:5.21771
# [828]	validation-rmse:5.21771
# [829]	validation-rmse:5.21749
# [829]	validation-rmse:5.21749
# [830]	validation-rmse:5.21752
# [830]	validation-rmse:5.21752
# [831]	validation-rmse:5.21750
# [831]	validation-rmse:5.21750
# [832]	validation-rmse:5.21763
# [832]	validation-rmse:5.21763
# [833]	validation-rmse:5.21761
# [833]	validation-rmse:5.21761
# [834]	validation-rmse:5.21764
# [834]	validation-rmse:5.21764
# [835]	validation-rmse:5.21827
# [835]	validation-rmse:5.21827
# [836]	validation-rmse:5.21819
# [836]	validation-rmse:5.21819
# [837]	validation-rmse:5.21813
# [837]	validation-rmse:5.21813
# [838]	validation-rmse:5.21819
# [838]	validation-rmse:5.21819
# [839]	validation-rmse:5.21855
# [839]	validation-rmse:5.21855
# [840]	validation-rmse:5.21839
# [840]	validation-rmse:5.21839
# [841]	validation-rmse:5.21851
# [841]	validation-rmse:5.21851
# [842]	validation-rmse:5.21877
# [842]	validation-rmse:5.21877?, ?trial/s, best loss=?]
# [843]	validation-rmse:5.21870
# [843]	validation-rmse:5.21870
# [844]	validation-rmse:5.21856
# [844]	validation-rmse:5.21856
# [845]	validation-rmse:5.21841
# [845]	validation-rmse:5.21841
# [846]	validation-rmse:5.21815
# [846]	validation-rmse:5.21815
# [847]	validation-rmse:5.21817
# [847]	validation-rmse:5.21817
# [848]	validation-rmse:5.21853
# [848]	validation-rmse:5.21853
# [849]	validation-rmse:5.21835
# [849]	validation-rmse:5.21835
# [850]	validation-rmse:5.21821
# [850]	validation-rmse:5.21821
# [851]	validation-rmse:5.21804
# [851]	validation-rmse:5.21804
# [852]	validation-rmse:5.21793
# [852]	validation-rmse:5.21793
#   0%|          | 0/50 [00:50<?, ?trial/s, best loss=?]
# ERROR [hyperopt.fmin] job exception: got an unexpected keyword argument 'squared'
#   0%|          | 0/50 [00:53<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[24], line 13, in objective(params)
#       5     booster = xgb.train(
#       6         params=params,
#       7         dtrain=train,
#    (...)
#      10         early_stopping_rounds=50
#      11     )
#      12     y_pred = booster.predict(valid)
# ---> 13     rmse = mean_squared_error(y_val, y_pred, squared=False)
#      14     mlflow.log_metric("rmse", rmse)
#      16 return {'loss': rmse, 'status': STATUS_OK}
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/inspect.py:3045, in Signature.bind(self, *args, **kwargs)
#    3040 def bind(self, /, *args, **kwargs):
#    3041     """Get a BoundArguments object, that maps the passed `args`
#    3042     and `kwargs` to the function's signature.  Raises `TypeError`
#    3043     if the passed arguments can not be bound.
#    3044     """
# -> 3045     return self._bind(args, kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/inspect.py:3034, in Signature._bind(self, args, kwargs, partial)
#    3032         arguments[kwargs_param.name] = kwargs
#    3033     else:
# -> 3034         raise TypeError(
#    3035             'got an unexpected keyword argument {arg!r}'.format(
#    3036                 arg=next(iter(kwargs))))
#    3038 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'
